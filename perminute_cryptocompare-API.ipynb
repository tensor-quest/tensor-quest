# %%
import requests
from config import cckey
import pandas as pd
import sys, json
import json
import datetime

# Get hourly market data for the following cryptocurrencies:

#1.	Bitcoin     BTC
#2.	Ethereum    ETH
#3.	XRP         XRP
#4.	Tether      USDT
#5.	Cardano     ADA
#6.	Monero      XMR
#7.	Stellar     XLM
#8.	BinanceUSD  BUSD
#9. Litecoin    LTC
#10.Dogecoin    DOGE

symbols=['BTC','ETH','XRP','USDT','ADA','XMR','XLM','BNB','LTC','DOGE']
#symbols=['BNB']
for symbol in symbols:

    df = results = pd.DataFrame()
    url = 'https://min-api.cryptocompare.com/data/v2/histominute?'

    # Initial toTimeStamp is set to -1 (up to the timestamp of the call)
    totime = 0
    while (1):
        params = {'fsym':symbol,'tsym':'USD','limit':'2000','toTs':totime-1,'api_key':cckey}
        response = requests.get(url, params=params).json()
        if response['Response'] != 'Success':
            break

        # Append the 2000 rows of data to the dataframe
        i = len(response['Data']['Data'])-1
        while (i >= 0):
            data = response['Data']['Data'][i]
            results = pd.DataFrame(data=response['Data']['Data'][i],index=['time'])
            df = df.append(results.set_index('time'))
            i -= 1
            
        # Stop when we reach the hour of BTC Genesis
        totime = response['Data']['TimeFrom']
        if len(df) > 60*24*7*2:
            break
            
        # Report status
        print("Got to timestamp "+str(totime)+' '+str( datetime.datetime.fromtimestamp(totime)))
        
    # Report final status and save csv file
    print("  Got to timestamp "+str(totime)+' '+str( datetime.datetime.fromtimestamp(totime)))
    print("  Done with "+symbol)
    df.to_csv("perminute_"+symbol+"set3.csv")

print("Done with everything.")
# Out:
# Got to timestamp 1643957520 2022-02-03 22:52:00
# Got to timestamp 1643837460 2022-02-02 13:31:00
# Got to timestamp 1643717400 2022-02-01 04:10:00
# Got to timestamp 1643597340 2022-01-30 18:49:00
# Got to timestamp 1643477280 2022-01-29 09:28:00
# Got to timestamp 1643472720 2022-01-29 08:12:00
#   Got to timestamp 1643472720 2022-01-29 08:12:00
#   Done with BTC
# Got to timestamp 1643957520 2022-02-03 22:52:00
# Got to timestamp 1643837460 2022-02-02 13:31:00
# Got to timestamp 1643717400 2022-02-01 04:10:00
# Got to timestamp 1643597340 2022-01-30 18:49:00
# Got to timestamp 1643477280 2022-01-29 09:28:00
# Got to timestamp 1643472720 2022-01-29 08:12:00
#   Got to timestamp 1643472720 2022-01-29 08:12:00
#   Done with ETH
# Got to timestamp 1643957520 2022-02-03 22:52:00
# Got to timestamp 1643837460 2022-02-02 13:31:00
# Got to timestamp 1643717400 2022-02-01 04:10:00
# Got to timestamp 1643597340 2022-01-30 18:49:00
# Got to timestamp 1643477280 2022-01-29 09:28:00
# Got to timestamp 1643472780 2022-01-29 08:13:00
#   Got to timestamp 1643472780 2022-01-29 08:13:00
#   Done with XRP
